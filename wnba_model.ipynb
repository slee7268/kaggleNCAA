# %%
import pandas as pd
import numpy as np

# %%
wncaa=pd.read_csv("wnba.csv")

# %%
wncaa.head()
# Out:
#    Unnamed: 0  TeamID  Season  games  totalMargin  Wins  Losses     Points  \
# 0           0  3102.0  2010.0     28   -19.964286     1      27  51.821429
# 1           1  3103.0  2010.0     30     2.600000    17      13  62.233333
# 2           2  3104.0  2010.0     29    -2.862069    11      18  64.137931
# 3           3  3105.0  2010.0     27    -3.962963    14      13  60.777778
# 4           4  3106.0  2010.0     29    -2.275862    12      17  55.137931
#
#           FG        FGA    ...           FGA3         FT        FTA  \
# 0  19.142857  53.142857    ...      16.071429   8.964286  13.214286
# 1  22.233333  55.266667    ...      12.466667  13.833333  19.600000
# 2  24.724138  62.103448    ...      14.724138  10.344828  16.793103
# 3  20.370370  50.851852    ...       9.888889  17.000000  24.333333
# 4  18.448276  53.000000    ...       9.586207  15.551724  24.000000
#
#           OR         DR        Ast         To       Stl       Blk         Pf
# ...

# %%
wncaa.head()
wncaa=wncaa.iloc[:,1:]
wncaa.to_csv("wnba.csv")

# %%
wncaa.columns
# Out:
# Index(['TeamID', 'Season', 'games', 'totalMargin', 'Wins', 'Losses', 'Points',
#        'FG', 'FGA', 'FG3', 'FGA3', 'FT', 'FTA', 'OR', 'DR', 'Ast', 'To', 'Stl',
#        'Blk', 'Pf'],
#       dtype='object')

# %%
tourn = pd.read_csv("google-cloud-ncaa-march-madness-2020-division-1-womens-tournament/WDataFiles_Stage1/WNCAATourneyDetailedResults.csv")

# %%
sample=pd.read_csv("google-cloud-ncaa-march-madness-2020-division-1-womens-tournament/WSampleSubmissionStage1_2020.csv")

# %%
sample.head()
# Out:
#                ID  Pred
# 0  2015_3106_3107   0.5
# 1  2015_3106_3110   0.5
# 2  2015_3106_3113   0.5
# 3  2015_3106_3114   0.5
# 4  2015_3106_3116   0.5

# %%
#separate ID column. into Season, Team 1 and Team 2

# %%
id = sample["ID"].str.split("_", n = 2, expand = True)
print(id)
# Out:
#           0     1     2
# 0      2015  3106  3107
# 1      2015  3106  3110
# 2      2015  3106  3113
# 3      2015  3106  3114
# 4      2015  3106  3116
# 5      2015  3106  3124
# 6      2015  3106  3129
# 7      2015  3106  3140
# 8      2015  3106  3143
# 9      2015  3106  3151
# 10     2015  3106  3163
# 11     2015  3106  3169
# 12     2015  3106  3173
# 13     2015  3106  3177
# 14     2015  3106  3181
# 15     2015  3106  3195
# 16     2015  3106  3199
# 17     2015  3106  3203
# 18     2015  3106  3211
# 19     2015  3106  3234
# 20     2015  3106  3235
# 21     2015  3106  3241
# 22     2015  3106  3246
# 23     2015  3106  3251
# 24     2015  3106  3257
# 25     2015  3106  3261
# 26     2015  3106  3268
# 27     2015  3106  3274
# 28     2015  3106  3278
# 29     2015  3106  3280
# ...     ...   ...   ...
# 10050  2019  3393  3417
# 10051  2019  3393  3460
# 10052  2019  3397  3400
# 10053  2019  3397  3401
# 10054  2019  3397  3406
# 10055  2019  3397  3413
# ...

# %%
sample["years"] = id[0]
sample ["team1"] = id[1]
sample ["team2"] = id[2]
print (sample)
# Out:
#                    ID  Pred years team1 team2
# 0      2015_3106_3107   0.5  2015  3106  3107
# 1      2015_3106_3110   0.5  2015  3106  3110
# 2      2015_3106_3113   0.5  2015  3106  3113
# 3      2015_3106_3114   0.5  2015  3106  3114
# 4      2015_3106_3116   0.5  2015  3106  3116
# 5      2015_3106_3124   0.5  2015  3106  3124
# 6      2015_3106_3129   0.5  2015  3106  3129
# 7      2015_3106_3140   0.5  2015  3106  3140
# 8      2015_3106_3143   0.5  2015  3106  3143
# 9      2015_3106_3151   0.5  2015  3106  3151
# 10     2015_3106_3163   0.5  2015  3106  3163
# 11     2015_3106_3169   0.5  2015  3106  3169
# 12     2015_3106_3173   0.5  2015  3106  3173
# 13     2015_3106_3177   0.5  2015  3106  3177
# 14     2015_3106_3181   0.5  2015  3106  3181
# 15     2015_3106_3195   0.5  2015  3106  3195
# 16     2015_3106_3199   0.5  2015  3106  3199
# 17     2015_3106_3203   0.5  2015  3106  3203
# 18     2015_3106_3211   0.5  2015  3106  3211
# ...

# %%
tourn.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2010     138     3124      69     3201      55    N      0    28    57
# 1    2010     138     3173      67     3395      66    N      0    23    59
# 2    2010     138     3181      72     3214      37    H      0    26    57
# 3    2010     138     3199      75     3256      61    H      0    25    63
# 4    2010     138     3207      62     3265      42    N      0    24    68
#
#    ...  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0  ...     34     3     5   17   19    12   18     4     1   18
# 1  ...     27    14    15   18   26     8    8     8     6   22
# 2  ...     15     3     8   10   21     4   16     6     4   20
# 3  ...     20    17    22   16   21    13   16     5     4   24
# 4  ...     26    11    17   16   22     9   10     3     4   12
#
# [5 rows x 34 columns]
