# %%
import pandas as pd

# %%
wncaa=pd.read_csv("wnba.csv")

# %%
wncaa.head()
# Out:
#    Unnamed: 0  TeamID  Season  games  totalMargin  Wins  Losses     Points  \
# 0           0  3102.0  2010.0     28   -19.964286     1      27  51.821429
# 1           0  3103.0  2010.0     30     2.600000    17      13  62.233333
# 2           0  3104.0  2010.0     29    -2.862069    11      18  64.137931
# 3           0  3105.0  2010.0     27    -3.962963    14      13  60.777778
# 4           0  3106.0  2010.0     29    -2.275862    12      17  55.137931
#
#           FG        FGA  ...       FGA3         FT        FTA         OR  \
# 0  19.142857  53.142857  ...  16.071429   8.964286  13.214286  12.464286
# 1  22.233333  55.266667  ...  12.466667  13.833333  19.600000  14.200000
# 2  24.724138  62.103448  ...  14.724138  10.344828  16.793103  14.482759
# 3  20.370370  50.851852  ...   9.888889  17.000000  24.333333  13.666667
# 4  18.448276  53.000000  ...   9.586207  15.551724  24.000000  15.000000
#
#           DR        Ast         To       Stl       Blk         Pf
# 0  19.535714  10.250000  17.714286  6.035714  0.642857  14.964286
# 1  23.566667  13.433333  18.266667  8.033333  2.400000  17.533333
# 2  25.931034  13.103448  19.172414  7.379310  2.931034  20.413793
# 3  23.370370   9.740741  25.037037  8.777778  5.148148  19.148148
# 4  24.758621  11.482759  20.103448  8.034483  4.482759  22.068966
#
# [5 rows x 21 columns]

# %%
wncaa.columns
# Out:
# Index(['Unnamed: 0', 'TeamID', 'Season', 'games', 'totalMargin', 'Wins',
#        'Losses', 'Points', 'FG', 'FGA', 'FG3', 'FGA3', 'FT', 'FTA', 'OR', 'DR',
#        'Ast', 'To', 'Stl', 'Blk', 'Pf'],
#       dtype='object')

# %%
tourn = pd.read_csv("google-cloud-ncaa-march-madness-2020-division-1-womens-tournament/WDataFiles_Stage1/WNCAATourneyDetailedResults.csv")

# %%
sample=pd.read_csv("google-cloud-ncaa-march-madness-2020-division-1-womens-tournament/WSampleSubmissionStage1_2020.csv")

# %%
sample.head()
# Out:
#                ID  Pred
# 0  2015_3106_3107   0.5
# 1  2015_3106_3110   0.5
# 2  2015_3106_3113   0.5
# 3  2015_3106_3114   0.5
# 4  2015_3106_3116   0.5

# %%
#separate ID column. into Season, Team 1 and Team 2

# %%
tourn.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2010     138     3124      69     3201      55    N      0    28    57
# 1    2010     138     3173      67     3395      66    N      0    23    59
# 2    2010     138     3181      72     3214      37    H      0    26    57
# 3    2010     138     3199      75     3256      61    H      0    25    63
# 4    2010     138     3207      62     3265      42    N      0    24    68
#
#    ...  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0  ...     34     3     5   17   19    12   18     4     1   18
# 1  ...     27    14    15   18   26     8    8     8     6   22
# 2  ...     15     3     8   10   21     4   16     6     4   20
# 3  ...     20    17    22   16   21    13   16     5     4   24
# 4  ...     26    11    17   16   22     9   10     3     4   12
#
# [5 rows x 34 columns]
